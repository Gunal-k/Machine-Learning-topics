# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/Gunal-k/Datasets/refs/heads/main/sample_data.csv'
data = pd.read_csv(url)
data.head()
# Out:
#    Admission  CGPA
# 0          0   4.2
# 1          0   5.1
# 2          0   5.5
# 3          1   8.2
# 4          1   9.0

# %%
X = data[['CGPA']]
y = data['Admission']

# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

lr = LogisticRegression()

lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

print(f"Predicted Admission: {y_pred}")

# Calculate and print accuracy score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Predicted Admission: [1 1]
# Accuracy: 100.00%

# %%
# Scatter plot
plt.scatter(X['CGPA'], y, color='blue', label='Data points')

plt.xlabel('CGPA')
plt.ylabel('Admission')
plt.title('CGPA vs Admission with Line Connecting Points')
plt.legend()
plt.show()
